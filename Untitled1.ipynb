# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

plt.style.use('fivethirtyeight')
# %matplotlib inline

# %%
data_csv = 'data3.csv'
data = pd.read_csv(data_csv, header=[1])

# %%
data.columns=['second','volt1','ampere','volt2']

# %%
data=data[1:]

# %%
data.head()
# Out:
#      second     volt1    ampere     volt2
# 1 -0.000599 -4.020101  0.000000 -0.477387
# 2 -0.000598 -4.020101  0.000000 -0.477387
# 3 -0.000597 -4.020101  0.502513 -0.276382
# 4 -0.000596 -4.020101  0.000000 -0.477387
# 5 -0.000595 -3.517588  0.000000 -0.326633

# %%
index=data['second']

# %%
data.set_index('second')
# Out:
#                volt1    ampere     volt2
# second
# -0.000599  -4.020101  0.000000 -0.477387
# -0.000598  -4.020101  0.000000 -0.477387
# -0.000597  -4.020101  0.502513 -0.276382
# -0.000596  -4.020101  0.000000 -0.477387
# -0.000595  -3.517588  0.000000 -0.326633
# -0.000594  -4.020101  0.000000 -0.276382
# -0.000593  -3.517588  0.000000 -0.477387
# -0.000592  -4.020101  0.000000 -0.477387
# -0.000591  -2.010050  0.502513 -0.477387
# -0.000590  -4.020101  0.000000 -0.276382
# -0.000589  -2.512563  0.000000 -0.276382
# -0.000588  -4.020101  2.010050 -0.477387
# -0.000587  -3.517588  0.000000 -0.477387
# -0.000586  -4.020101  0.000000 -0.477387
# -0.000585  -4.020101  0.000000 -0.477387
# -0.000584  -4.020101  0.000000 -0.477387
# -0.000583  -4.020101  0.000000 -0.326633
# -0.000582  -4.020101  1.005025 -0.477387
# -0.000581  -4.020101  0.000000 -0.477387
# -0.000580  -4.020101  0.000000 -0.276382
# -0.000579  -4.020101  0.502513 -0.326633
# -0.000578  -3.015075  2.010050 -0.376885
# ...

# %%
floatdata=data.astype(float)

# %%
floatdata.dtypes
# Out:
# second    float64
# volt1     float64
# ampere    float64
# volt2     float64
# dtype: object

# %%
floatdata.plot(xlim=(-0.0008,0.0015), sharex=False,kind='scatter', y=['ampere','volt1','volt2'], x=['second','second','second'], color=['r','b','g'], figsize=(8,8))

# %%
floatdata1=floatdata.loc[575:725,:]

# %%
t = floatdata1['second']
data1 = floatdata1['volt1']
data2 = floatdata1['ampere']
data3 = floatdata1['volt2']

fig, ax1 = plt.subplots(figsize=(20,10))

color = 'tab:red'
ax1.set_xlabel('time (us)', fontsize=50)
ax1.set_ylabel('Voltage', color=color,fontsize=50)
ax1.plot(t, data1, color='g',)
ax1.plot(t, data3, color='r')

ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis

color = 'tab:blue'
ax2.set_ylabel('Current', color=color,fontsize=50)  # we already handled the x-label with ax1
ax2.plot(t, data2, color=color)

ax2.tick_params(axis='y', labelcolor=color)
